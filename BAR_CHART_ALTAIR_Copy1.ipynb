# %% [markdown]
# <a href="https://colab.research.google.com/github/AuFilDuBoamp/ap_binder_voila/blob/main/BAR_CHART_ALTAIR_Copy1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BAR CHART ALTAIR

# %%
import pandas as pd

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

import altair as alt

# %%
# import données
# https://www.data.gouv.fr/fr/datasets/la-table-boamp-siren-acheteurs-80-daufilduboamp/
df = pd.read_parquet('https://www.data.gouv.fr/fr/datasets/r/4b77da19-3834-4a12-9626-9aedd75d168a')
#dft2 = pd.read_parquet('../0000_PREPA_BOAMP_NOTNA_2024_POUR_PATCH/EXPORT_AFDB_MERGE_PREPARE/boamp_siren_acheteurs_trimestre_2_2024_80_colonnes.parquet')

# %%
#df = pd.concat([dft1, dft2]).copy()
df.shape
# Out:
# (33080, 80)

# %%
df.head()
# Out:
#   B_01_annonceLie B_02_annonceReferenceSchemaV110  \
# 0       23-140829                            <NA>
# 1            <NA>                            <NA>
# 2        23-80829                            <NA>
# 3        23-43044                            <NA>
# 4       23-135720                            <NA>
#
#   B_03_annoncesAnterieuresSchemaV110 B_04_codeDepartement  \
# 0                               <NA>                   78
# 1                               <NA>                   42
# 2                               <NA>                   75
# 3                               <NA>                   75
# 4                               <NA>                   33
#
#   B_05_codeDepartementPrestation     B_06_criteres B_07_dateFinDiffusion  \
# 0                           <NA>  environnementaux            2024-01-30
# 1                           <NA>              <NA>            2024-02-02
# 2                           <NA>              <NA>            2024-02-29
# 3                           <NA>              <NA>            2024-03-27
# 4                           <NA>  environnementaux            2024-03-28
#
#       B_08_dateLimiteReponse          B_09_dateParution           B_10_dc  \
# 0                       <NA>  2024-01-01 00:00:00+00:00               461
# 1  2024-02-02T12:00:00+01:00  2024-01-01 00:00:00+00:00  33,63,74,105,341
# 2                       <NA>  2024-01-01 00:00:00+00:00               274
# 3                       <NA>  2024-01-01 00:00:00+00:00               102
# 4                       <NA>  2024-01-01 00:00:00+00:00    52,155,274,403
#
#   B_11_descripteurCode                            B_12_descripteurLibelle  \
# 0                  461                    Mise à disposition de personnel
# 1     33,63,74,105,341  Bâtiment,Cloison, faux plafond,Couverture,Elec...
# 2                  274                            Prestations de services
# 3                  102                                   Eclairage public
# 4       52,155,274,403  Carburant, hydrocarbure,Hydrocarbures naturels...
#
#   B_13_etat B_14_famille                      B_15_familleLibelle  \
# 0   INITIAL         JOUE                        Marchés européens
# 1   INITIAL          FNS  Marchés entre 90 k€ et seuils européens
# 2   INITIAL         JOUE                        Marchés européens
# 3   INITIAL         JOUE                        Marchés européens
# 4   INITIAL         JOUE                        Marchés européens
#
#                B_16_filename B_17_idweb B_18_marchePublicSimplifie  \
# 0  BOAMP-J-IC-AA_2024_001005  23-181344                       <NA>
# 1     BOAMP-N-AO_2024_001003       24-8                       <NA>
# 2  BOAMP-J-IC-AA_2024_001005  23-181350                       <NA>
# 3  BOAMP-J-IC-AA_2024_001002  23-181304                       <NA>
# 4  BOAMP-J-IC-AA_2024_001005  23-181324                       <NA>
#
#   B_19_marchePublicSimplifieLabel  B_20_nature B_21_natureCategorise  \
# 0                            <NA>  ATTRIBUTION  attribution/standard
# 1                            <NA>  APPEL_OFFRE   appeloffre/standard
# 2                            <NA>  ATTRIBUTION  attribution/standard
# 3                            <NA>  ATTRIBUTION  attribution/standard
# 4                            <NA>  ATTRIBUTION  attribution/standard
#
#   B_22_natureCategoriseLibelle  B_23_natureLibelle  \
# 0          Résultat de marché/  Résultat de marché
# 1              Avis de marché/      Avis de marché
# 2          Résultat de marché/  Résultat de marché
# 3          Résultat de marché/  Résultat de marché
# 4          Résultat de marché/  Résultat de marché
#
#                          B_24_nomAcheteur  \
# 0  Le Syndicat Intercommunal d'aménagemen
# 1                     Commune de SORBIERS
# 2                       CAISSE DES DEPOTS
# 3                  PORT AUTONOME DE PARIS
# 4               Ville de La Teste de Buch
#
#                                           B_25_objet B_26_perimetre  \
# 0  Accueil, information et médiation pour le Chât...   DIRECTIVE-24
# 1  Construction d'une médiathèque/tiers-lieu et r...       FNSimple
# 2  Prestations de commissariat aux comptes pour l...   DIRECTIVE-24
# 3  Accord-cadre mono-attributaire _ Travaux d'ins...   DIRECTIVE-24
# 4  Fourniture à la pompe de carburants automobile...   DIRECTIVE-24
#
#   B_27_procedureCategorise B_28_procedureLibelle B_29_sourceSchema  \
# 0                  OUVERT/     Procédure Ouverte              <NA>
# 1                  OUVERT/     Procédure Ouverte              <NA>
# 2                  OUVERT/     Procédure Ouverte              <NA>
# 3                  OUVERT/     Procédure Ouverte              <NA>
# 4                  OUVERT/     Procédure Ouverte              <NA>
#
#   B_30_sousNature B_31_sousNatureLibelle B_32_sousTypeProcedure  \
# 0        STANDARD                   <NA>                   <NA>
# 1        STANDARD                   <NA>                   <NA>
# 2        STANDARD                   <NA>                   <NA>
# 3        STANDARD                   <NA>                   <NA>
# 4        STANDARD                   <NA>                   <NA>
#
#                                       B_33_titulaire B_34_typeAvis  \
# 0                                              MUSEA         ,10,6
# 1                                               <NA>          5,1,
# 2                               DELOITTE ET ASSOCIES         ,10,6
# 3  EIFFAGE ENERGIE SYSTEMES - ILE-DE-FRANCE,DALKI...         ,10,6
# 4  SOCIETE D'IMPORTATION EDOUARD LECLERC (SIPLEC)...         ,10,6
#
#   B_35_typeMarche B_36_typeMarcheFacette B_37_typeProcedure  \
# 0        SERVICES               Services             OUVERT
# 1         TRAVAUX                Travaux             OUVERT
# 2        SERVICES               Services             OUVERT
# 3         TRAVAUX                Travaux             OUVERT
# 4     FOURNITURES            Fournitures             OUVERT
#
#                                         B_38_urlAvis    B_39_id  \
# 0  https://www.boamp.fr/pages/avis/?q=idweb:23-18...  23_181344
# 1      https://www.boamp.fr/pages/avis/?q=idweb:24-8       24_8
# 2  https://www.boamp.fr/pages/avis/?q=idweb:23-18...  23_181350
# 3  https://www.boamp.fr/pages/avis/?q=idweb:23-18...  23_181304
# 4  https://www.boamp.fr/pages/avis/?q=idweb:23-18...  23_181324
#
#                                         B_40_GESTION  \
# 0  {"REFERENCE": {"IDWEB": "23-181344", "TYPE_AVI...
# 1  {"REFERENCE": {"IDWEB": "24-8", "TYPE_AVIS": {...
# 2  {"REFERENCE": {"IDWEB": "23-181350", "TYPE_AVI...
# 3  {"REFERENCE": {"IDWEB": "23-181304", "TYPE_AVI...
# 4  {"REFERENCE": {"IDWEB": "23-181324", "TYPE_AVI...
#
#                                B_41_GESTION_URL_JSON  \
# 0  https://www.aufilduboamp.com/partages/aufildub...
# 1  https://www.aufilduboamp.com/partages/aufildub...
# 2  https://www.aufilduboamp.com/partages/aufildub...
# 3  https://www.aufilduboamp.com/partages/aufildub...
# 4  https://www.aufilduboamp.com/partages/aufildub...
#
#                                         B_42_DONNEES  \
# 0  {"IDENTITE": {"DENOMINATION": "Le Syndicat Int...
# 1  {"IDENTITE": {"DENOMINATION": "Commune de SORB...
# 2  {"IDENTITE": {"DENOMINATION": "CAISSE DES DEPO...
# 3  {"IDENTITE": {"DENOMINATION": "PORT AUTONOME D...
# 4  {"IDENTITE": {"DENOMINATION": "Ville de La Tes...
#
#                                B_43_DONNEES_URL_JSON  \
# 0  https://www.aufilduboamp.com/partages/aufildub...
# 1  https://www.aufilduboamp.com/partages/aufildub...
# 2  https://www.aufilduboamp.com/partages/aufildub...
# 3  https://www.aufilduboamp.com/partages/aufildub...
# 4  https://www.aufilduboamp.com/partages/aufildub...
#
#                            B_44_ANNONCES_ANTERIEURES  \
# 0  {"REFERENCE": {"IDWEB": "23-140829", "TYPE_AVI...
# 1                                               <NA>
# 2  {"REFERENCE": {"IDWEB": "23-80829", "TYPE_AVIS...
# 3  {"REFERENCE": {"IDWEB": "23-43044", "TYPE_AVIS...
# 4  {"REFERENCE": {"IDWEB": "23-135720", "TYPE_AVI...
#
#                   B_45_ANNONCES_ANTERIEURES_URL_JSON  \
# 0  https://www.aufilduboamp.com/partages/aufildub...
# 1                                               <NA>
# 2  https://www.aufilduboamp.com/partages/aufildub...
# 3  https://www.aufilduboamp.com/partages/aufildub...
# 4  https://www.aufilduboamp.com/partages/aufildub...
#
#   B_46_SIRET_ACHETEURS_BRUTS SN_01_activitePrincipaleUniteLegale  \
# 0                       <NA>                              84.11Z
# 1             21420302800011                              84.11Z
# 2                       <NA>                              64.19Z
# 3                       <NA>                              52.22Z
# 4                       <NA>                              84.11Z
#
#   SN_02_anneeCategorieEntreprise SN_03_anneeEffectifsUniteLegale  \
# 0                           2021                            2021
# 1                           2021                            2021
# 2                           2021                            2021
# 3                           2021                            2021
# 4                           2021                            2021
#
#   SN_04_caractereEmployeurUniteLegale SN_05_categorieEntreprise  \
# 0                                <NA>                       PME
# 1                                <NA>                       PME
# 2                                <NA>                        GE
# 3                                <NA>                       PME
# 4                                <NA>                       ETI
#
#   SN_06_categorieJuridiqueUniteLegale SN_07_dateCreationUniteLegale  \
# 0                                7354                    1980-01-01
# 1                                7210                    1983-03-01
# 2                                7490                    1982-01-01
# 3                                4110                    1971-01-01
# 4                                7210                    1980-01-01
#
#   SN_08_dateDebut SN_09_dateDernierTraitementUniteLegale  \
# 0      2021-11-08                    2024-03-22T14:26:06
# 1      2009-12-17                    2024-03-22T14:26:06
# 2      2018-12-31                    2024-03-22T14:26:06
# 3      2021-06-01                    2024-03-22T14:26:06
# 4      2021-12-31                    2024-03-22T14:26:06
#
#                        SN_10_denominationUniteLegale  \
# 0  SYNDICAT INTERCOMMUNAL A VOCATION MULTIPLE DE ...
# 1                                COMMUNE DE SORBIERS
# 2                 CAISSE DES DEPOTS ET CONSIGNATIONS
# 3                             PORT AUTONOME DE PARIS
# 4                        COMMUNE DE LA TESTE DE BUCH
#
#   SN_11_denominationUsuelle1UniteLegale SN_12_denominationUsuelle2UniteLegale  \
# 0                                  <NA>                                  <NA>
# 1                                  <NA>                                  <NA>
# 2                                  <NA>                                  <NA>
# 3                                  <NA>                                  <NA>
# 4                                  <NA>                                  <NA>
#
#   SN_13_denominationUsuelle3UniteLegale  \
# 0                                  <NA>
# 1                                  <NA>
# 2                                  <NA>
# 3                                  <NA>
# 4                                  <NA>
#
#   SN_14_economieSocialeSolidaireUniteLegale  \
# 0                                         N
# 1                                         N
# 2                                         N
# 3                                         N
# 4                                         N
#
#   SN_15_etatAdministratifUniteLegale SN_16_identifiantAssociationUniteLegale  \
# 0                                  A                                    <NA>
# 1                                  A                                    <NA>
# 2                                  A                                    <NA>
# 3                                  C                                    <NA>
# 4                                  A                                    <NA>
#
#   SN_17_nicSiegeUniteLegale SN_18_nomUniteLegale SN_19_nomUsageUniteLegale  \
# 0                     00011                 <NA>                      <NA>
# 1                     00011                 <NA>                      <NA>
# 2                     00019                 <NA>                      <NA>
# 3                     00018                 <NA>                      <NA>
# 4                     00254                 <NA>                      <NA>
#
#   SN_20_nombrePeriodesUniteLegale  \
# 0                               6
# 1                               5
# 2                               5
# 3                               5
# 4                               6
#
#   SN_21_nomenclatureActivitePrincipaleUniteLegale SN_22_prenom1UniteLegale  \
# 0                                         NAFRev2                     <NA>
# 1                                         NAFRev2                     <NA>
# 2                                         NAFRev2                     <NA>
# 3                                         NAFRev2                     <NA>
# 4                                         NAFRev2                     <NA>
#
#   SN_23_prenom2UniteLegale SN_24_prenom3UniteLegale SN_25_prenom4UniteLegale  \
# 0                     <NA>                     <NA>                     <NA>
# 1                     <NA>                     <NA>                     <NA>
# 2                     <NA>                     <NA>                     <NA>
# 3                     <NA>                     <NA>                     <NA>
# 4                     <NA>                     <NA>                     <NA>
#
#   SN_26_prenomUsuelUniteLegale SN_27_pseudonymeUniteLegale  \
# 0                         <NA>                        <NA>
# 1                         <NA>                        <NA>
# 2                         <NA>                        <NA>
# 3                         <NA>                        <NA>
# 4                         <NA>                        <NA>
#
#   SN_28_sexeUniteLegale SN_29_sigleUniteLegale SN_30_siren  \
# 0                  <NA>                   <NA>   247800055
# 1                  <NA>                   <NA>   214203028
# 2                  <NA>                    CDC   180020026
# 3                  <NA>                    PAP   712032143
# 4                  <NA>                   <NA>   213305295
#
#   SN_31_societeMissionUniteLegale SN_32_statutDiffusionUniteLegale  \
# 0                            <NA>                                O
# 1                            <NA>                                O
# 2                            <NA>                                O
# 3                            <NA>                                O
# 4                            <NA>                                O
#
#   SN_33_trancheEffectifsUniteLegale SN_34_unitePurgeeUniteLegale
# 0                                03                         <NA>
# 1                                22                         <NA>
# 2                                52                         <NA>
# 3                                00                         <NA>
# 4                                41                         <NA>

# %%
df2 = (df.SN_10_denominationUniteLegale
       .value_counts()
       .sort_values(ascending=False)[0:5]
       .to_frame()
       .reset_index(drop=False)
       .rename(columns={'count': 'DECOMPTE', 'SN_10_denominationUniteLegale': 'NOM'})
       .copy()
      )

# %%
df2
# Out:
#                                      NOM  DECOMPTE
# 0  SCE DEPARTEMENTAL INCENDIE ET SECOURS       383
# 1                   MINISTERE DES ARMEES       311
# 2                         VILLE DE PARIS       244
# 3                     BORDEAUX METROPOLE       158
# 4  ASSISTANCE PUBLIQUE HOPITAUX DE PARIS       147

# %%
# mark_point()
# mark_circle()
# mark_square()
# mark_line()
# mark_area()
# mark_bar()
# mark_tick()
#
# Les canaux d’encodage les plus fréquents sont:
#
# x 	abscisse
# y 	ordonnée
# color 	couleur de la marque
# opacity 	transparence/opacité de la marque
# shape 	forme de la marque
# size 	taille de la marque
# facet 	répétition du canal

# %%
chart = alt.Chart(df2).mark_bar().encode(
    alt.X('DECOMPTE:Q'),
    alt.Y('NOM:N', sort='x'),
    alt.Color("NOM:N")

)

chart
# Out:
# alt.Chart(...)

# %%
chart = alt.Chart(df2).mark_bar(color='firebrick').encode(
    alt.X(field='DECOMPTE', type='quantitative'),
    alt.Y(field='NOM', type='nominal', sort='x'),
    #alt.Color(field='NOM', type='nominal')


)

chart
# Out:
# alt.Chart(...)

# %%
chart = alt.Chart(df2, title='MON_TITRE').mark_bar().encode(
    alt.X(field='DECOMPTE', type='quantitative', title='DECOMPTE #2'),
    alt.Y(field='NOM', type='nominal', sort='x', title='NOM #2'),
    alt.Color(field='NOM', type='nominal')


)

chart
# Out:
# alt.Chart(...)
